# %%
# 필요한 모듈 설치

#pillow : 사진 관련 모듈
#requests : 인터넷 연결 관련 모듈

# !pip install pillow    
# !pip install requests

# %%
import matplotlib.pyplot as plt    #그림 관련
import matplotlib.image as mpimg   #사진 관련

#생략 가능 : 브라우저 상의 그림 표현
# %matplotlib inline

# %%
img = mpimg.imread('face1.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
#유명인 얼굴과 얼마나 비슷한지 검색

import requests # 인터넷 연결

client_id = "QK8slKhjtU0rao3IlVEa"  #네이버 API ID
client_secret = "SsrSzlLgdw"        #네이버 API 비밀번호

url = "https://openapi.naver.com/v1/vision/celebrity"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-id':client_id, 'X-Naver-Client-secret':client_secret}

response = requests.post(url,files = files, headers = headers)

# %%
# import json  #json 형식을 다루는 모듈
# parsed = json.loads(response.text)
# print(json.dumps(parsed, indent = 4, sort_keys = False, ensure_ascii = False))

import json   # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys = False, ensure_ascii = False))  #indent = 들여쓰기

#사진 1장의 최대 크기는 2MB로 제한
# Out:
# {
#     "info": {
#         "size": {
#             "width": 680,
#             "height": 400
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "celebrity": {
#                 "value": "김수현",
#                 "confidence": 0.287968
#             }
#         }
#     ]
# }

# %%
#얼굴 인식, 나이 예측, 감정 상태 등등 분석

import requests # 인터넷 연결

client_id = "QK8slKhjtU0rao3IlVEa"  #네이버 API ID
client_secret = "SsrSzlLgdw"        #네이버 API 비밀번호

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face3.jpg','rb')}
headers = {'X-Naver-Client-id':client_id, 'X-Naver-Client-secret':client_secret}

response = requests.post(url,files = files, headers = headers)

# %%
import json   # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys = False, ensure_ascii = False))  #indent = 들여쓰기

#사진 1장의 최대 크기는 2MB로 제한
# Out:
# {
#     "info": {
#         "size": {
#             "width": 512,
#             "height": 427
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 245,
#                 "y": 114,
#                 "width": 33,
#                 "height": 33
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 253,
#                     "y": 119
#                 },
#                 "rightEye": {
#                     "x": 269,
#                     "y": 119
#                 },
#                 "nose": {
#                     "x": 261,
#                     "y": 128
#                 },
#                 "leftMouth": {
#                     "x": 254,
#                     "y": 135
#                 },
#                 "rightMouth": {
#                     "x": 269,
#                     "y": 135
#                 }
#             },
#             "gender": {
# ...

# %%
##########################################################
#기본 문법 학습

# %%
# dict형과 json에 대해서

dict = {
    'Name':'pinkwink', 
    'Age':'None', 
    'Class':['beginner','blog']
}
dict
# Out:
# {'Name': 'pinkwink', 'Age': 'None', 'Class': ['beginner', 'blog']}

# %%
dict.keys(), dict.values(), dict.items()
# Out:
# (dict_keys(['Name', 'Age', 'Class']),
#  dict_values(['pinkwink', 'None', ['beginner', 'blog']]),
#  dict_items([('Name', 'pinkwink'), ('Age', 'None'), ('Class', ['beginner', 'blog'])]))

# %%
dict['Class']
# Out:
# ['beginner', 'blog']

# %%
dict.get('Name')  #key 값을 통해 value 값 불러오기
# Out:
# 'pinkwink'

# %%
dict.get('Age','nothing'), dict.get('Room','nothing')
# Out:
# ('None', 'nothing')

# %%
##########################################
# json (JavaScript Object Notation)

# %%
customer = {
    'id':'0001',
    'name':'홍길동',
    'history':[
        {'date':'2019-03-01', 'log':True},
        {'date':'2019-03-02', 'log':False},
    ]
}

# %%
import json
json_test = json.dumps(customer, indent = 4, ensure_ascii = False)
print(json_test)
# Out:
# {
#     "id": "0001",
#     "name": "홍길동",
#     "history": [
#         {
#             "date": "2019-03-01",
#             "log": true
#         },
#         {
#             "date": "2019-03-02",
#             "log": false
#         }
#     ]
# }

# %%
##############################################
#사진 위에 개인 정보 표시하기

# %%
img = mpimg.imread('face1.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
#얼굴 인식, 나이 예측, 감정 상태 등등 분석

import requests # 인터넷 연결

client_id = "QK8slKhjtU0rao3IlVEa"  #네이버 API ID
client_secret = "SsrSzlLgdw"        #네이버 API 비밀번호

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-id':client_id, 'X-Naver-Client-secret':client_secret}

response = requests.post(url,files = files, headers = headers)

# %%
import json   # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys = False, ensure_ascii = False))  #indent = 들여쓰기
# Out:
# {
#     "info": {
#         "size": {
#             "width": 680,
#             "height": 400
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 272,
#                 "y": 98,
#                 "width": 113,
#                 "height": 113
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 298,
#                     "y": 124
#                 },
#                 "rightEye": {
#                     "x": 350,
#                     "y": 129
#                 },
#                 "nose": {
#                     "x": 320,
#                     "y": 157
#                 },
#                 "leftMouth": {
#                     "x": 297,
#                     "y": 182
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 186
#                 }
#             },
#             "gender": {
# ...

# %%
parsed.keys(), parsed.values()
# Out:
# (dict_keys(['info', 'faces']),
#  dict_values([{'size': {'width': 680, 'height': 400}, 'faceCount': 1}, [{'roi': {'x': 272, 'y': 98, 'width': 113, 'height': 113}, 'landmark': {'leftEye': {'x': 298, 'y': 124}, 'rightEye': {'x': 350, 'y': 129}, 'nose': {'x': 320, 'y': 157}, 'leftMouth': {'x': 297, 'y': 182}, 'rightMouth': {'x': 343, 'y': 186}}, 'gender': {'value': 'male', 'confidence': 0.999998}, 'age': {'value': '30~34', 'confidence': 0.441697}, 'emotion': {'value': 'neutral', 'confidence': 1.0}, 'pose': {'value': 'frontal_face', 'confidence': 0.991977}}]]))

# %%
parsed['info']
# Out:
# {'size': {'width': 680, 'height': 400}, 'faceCount': 1}

# %%
parsed['faces'][0]['gender'] , parsed['faces'][0]['roi']
# Out:
# ({'value': 'male', 'confidence': 0.999998},
#  {'x': 272, 'y': 98, 'width': 113, 'height': 113})

# %%
parsed['faces'][0]['emotion']
# Out:
# {'value': 'neutral', 'confidence': 1.0}

# %%
x,y,w,h = parsed['faces'][0]['roi'].values()
x,y,w,h
# Out:
# (272, 98, 113, 113)

# %%
gender,gen_confi = parsed['faces'][0]['gender'].values()
gender, gen_confi
# Out:
# ('male', 0.999998)

# %%
emotion, emo_confi = parsed['faces'][0]['emotion'].values()
age, age_confi = parsed['faces'][0]['age'].values()

# %%
annotation = gender + " : " + str(gen_confi) + '\n' + emotion + " : " + str(emo_confi) + '\n' + age + " : " + str(age_confi)

# %%
print(annotation)
# Out:
# male : 0.999998
# neutral : 1.0
# 30~34 : 0.441697

# %%
import matplotlib.patches as patches

img = mpimg.imread('face1.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

rect_face = patches.Rectangle((x,y),w,h,
                             linewidth = 5,
                             edgecolor = 'r',
                             facecolor = 'none')
ax.add_patch(rect_face)

plt.text(10,400, annotation, wrap=True, fontsize = 17, color = 'white')
plt.show()

# %%
#얼굴 인식, 나이 예측, 감정상태 등등 분석 2

import requests # 인터넷 연결

client_id = "QK8slKhjtU0rao3IlVEa"  #네이버 API ID
client_secret = "SsrSzlLgdw"        #네이버 API 비밀번호

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face3.jpg','rb')}
headers = {'X-Naver-Client-id':client_id, 'X-Naver-Client-secret':client_secret}

response = requests.post(url,files = files, headers = headers)

# %%
import json   # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys = False, ensure_ascii = False))  #indent = 들여쓰기
# Out:
# {
#     "info": {
#         "size": {
#             "width": 512,
#             "height": 427
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 245,
#                 "y": 114,
#                 "width": 33,
#                 "height": 33
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 253,
#                     "y": 119
#                 },
#                 "rightEye": {
#                     "x": 269,
#                     "y": 119
#                 },
#                 "nose": {
#                     "x": 261,
#                     "y": 128
#                 },
#                 "leftMouth": {
#                     "x": 254,
#                     "y": 135
#                 },
#                 "rightMouth": {
#                     "x": 269,
#                     "y": 135
#                 }
#             },
#             "gender": {
# ...

# %%
import matplotlib.patches as patches

img = mpimg.imread('face3.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)


for each in parsed['faces'] :
    
    x,y,w,h = each['roi'].values()
    gender,gen_confi = each['gender'].values() 
    emotion, emo_confi = each['emotion'].values() 
    age, age_confi = each['age'].values() 
    
    rect_face = patches.Rectangle((x,y),w,h,
                             linewidth = 5,
                             edgecolor = 'r',
                             facecolor = 'none')
    ax.add_patch(rect_face)
    
    annotation = gender + " : " + str(round(gen_confi*100,2)) + "%" + '\n' + emotion + " : " + str(round(emo_confi*100,2)) + "%" + '\n' + age + " : " + str(round(age_confi*100,2)) + "%"
#     #윗줄(annotation) 보기 쉽게 정리
#     annotation = gender + " : " + str(round(gen_confi*100,2)) + "%" + '\n' 
#     + emotion + " : " + str(round(emo_confi*100,2)) + "%" + '\n' 
#     + age + " : " + str(round(age_confi*100,2)) + "%"

    plt.text(x-10,y-30, annotation, wrap=True, fontsize = 10, color = 'black')

plt.show()
